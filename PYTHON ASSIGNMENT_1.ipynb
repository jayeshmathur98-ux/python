# %% [markdown]
# # Topic: Python Data Types and Type Checking
# # Objective
#
# Learn:
#
# - Basic data types in Python
#
# - Variable creation
#
# - Using type() function
#
# - Taking user input
#
# - Type conversion

# %% [markdown]
# # Part A – Theory Questions

# %% [markdown]
# Q1. What is a variable in Python?

# %%
#variable in python are used as storage to store a data or things in python
name = "jayesh"
age = 19

# %% [markdown]
# Q2. What are Data Types in Python? Name all Commonly used data types in Python?

# %%
# data type are things that we store in variable and difine what data type are.python has built in data type for different kind of data.
# there are 3 type of data type 
#1)number 
a = 34
print(type(a))
b = 36.8
print(type(b))
c = 3 + 4j
print(type(c))
#2)string
a = "123344453553662366 SGSGDFFGDHDHDHDHNDJJS %%^&&&**&^^%%$####$%^"
print(type(a))
#3)boolen
a = True
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Q3. What is the difference between int and float?

# %% [markdown]
# # int = 1 store whole number 2 no decimal point 3-example 10,25,-9 4- used for counting 5- take less memory compared to float
# # float = 1- stores decimal point 2- has decimal point 3- example 7.0,9.3,383838.3993,83838.83838,3993939.93939 4= used for measurment 5= takes more memory

# %%
# in int there are integers(from infinite -2,-1,0,1,2,3 to infinite) 
#example 
a = -2345636
print(type(a))
# and in float there are only decimal number(36.8,84.5,374.48 ......)
#example
b = 54747484894.74848494
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Q4. What is type() function?

# %%
# type()function are used to check the data type od variable or value 
#example
x = 10 
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# # Part B – Practical Questions

# %% [markdown]
# Q1. Create variables of different data types?
#
#     INPUT -
#     name = "Rahul"
#     age = 22
#     height = 5.8
#     is_student = True
#
#     OUTPUT -
#     Rahul
#     22
#     5.8
#     True

# %%
name = "Rahu1"
print(name)
age = 22
print(age)
height = 5.8
print(height)
is_student = True 
print(is_student)
# Out:
# Rahu1
# 22
# 5.8
# True

# %% [markdown]
# Q2. Check Data Types using type()?
#
#     INPUT-
#     name = "YOUR NAME"
#     number = 100
#     decimal = 10.5
#     status = False
#
#     OUTPUT-
#     <class 'str'>
#     <class 'int'>
#     <class 'float'>
#     <class 'bool'>

# %%
name = "jayesh"
print(type(name))
number = 100
print(type(number))
decimal = 10.5
print(type(decimal))
status = False
print(type(status))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# Q3. Take user input and check type
#
#     INPUT-
#     name = "NIKHIL"
#
#     OUTPUT-
#     "NIKHIL"
#     <class 'str'>

# %%
name = "NIKHIL"
print("NIKHIL")
print(type(name))
# Out:
# NIKHIL
# <class 'str'>

# %% [markdown]
# Q4. Integer Type Conversion
#
#     INPUT-
#     num = "25"
#
#     OUTPUT-
#     25
#     <class 'int'>

# %%
num = "25"
num = int(num)
print(num)
print(type(int)(num))
# Out:
# 25
# <class 'int'>

# %% [markdown]
# Q5. Float Type Conversion
#
#     INPUT-
#     num = "10.5"
#
#     OUTPUT-
#     10.5
#     <class 'float'>

# %%
num = "10.5"
num = float(num)
print(num)
print(type(float)(num))
# Out:
# 10.5
# <class 'float'>

# %% [markdown]
# Q6. Convert int to float
#
#     INPUT-
#     num = 50
#     OUTPUT-
#     50.0
#     <class 'float'>

# %%
num = 50 
num = float(num)
print(num)
print(type(float)(num))
# Out:
# 50.0
# <class 'float'>

# %% [markdown]
# # Part C – Practice Programs

# %% [markdown]
# Q1. Create a mini student profile
#
#     INPUT-
#     name = "Amit"
#     age = 20
#     course = "Python"
#
#     OUTPUT-
#     Name: Amit
#     Age: 20
#     Course: Python

# %%
name = "Amit" 
age = 20
course = "Python"
print("Name:",name)
print("Age:",age)
print("Course:",course)
# Out:
# Name: Amit
# Age: 20
# Course: Python
